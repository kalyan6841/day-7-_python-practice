# %%
#number o days in a given month
def days_in_month(month):
    if month == 2:
        return 28
    elif month in [4,6,9,11]:
        return 30
    elif month in [1,3,5,7,8,9,10,12]:
        return 31
    else:
        return "invalid month"
month = int(input("enter month number (1-12): "))
print(days_in_month(month))
# Out:
# enter month number (1-12):  10
# 31

# %%
#BMI calculator
def calculate_bmi(weight, height):
    bmi = weight/(height*weight)
    if bmi< 18.5 :
        category = "under weight"
    elif bmi< 24.9:
        category = " normal weight"
    elif bmi< 29.9:
        category = "over height"
    else:
        category = "obese"
weight = float(input("enter weight in kg: "))
height = float (input("enter height in meters: "))
bmi, category = calculate_bmi(weight, height)
print("BMI:", round(bmi,2))
print("category:",category)
# Out:
# enter weight in kg:  70
# enter height in meters:  175
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 14
#      12 weight = float(input("enter weight in kg: "))
#      13 height = float (input("enter height in meters: "))
# ---> 14 bmi, category = calculate_bmi(weight, height)
#      15 print("BMI:", round(bmi,2))
#      16 print("category:",category)
#
# TypeError: cannot unpack non-iterable NoneType object
